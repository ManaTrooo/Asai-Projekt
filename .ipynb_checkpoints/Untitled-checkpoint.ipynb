# %%
import pandas as pd

# 💡 Absoluter Pfad – so kannst du die Datei direkt laden:
df = pd.read_csv(r"C:\Users\zahri\anaconda_projects\AsaiProjekt\Asai-Projekt\heart_2020_cleaned.csv")

# 🎨 DataFrame-Style für optisch ansprechende Ausgabe
styled_df = df.head(60).style.set_table_styles([
    {'selector': 'thead th', 'props': [('background-color', '#1f77b4'), ('color', 'white'), ('font-weight', 'bold')]},
    {'selector': 'tbody td', 'props': [('border', '1px solid #ddd'), ('text-align', 'center')]}
]).set_properties(**{'text-align': 'center'})

# 🎨 Optional: Hover-Effekt
styled_df.set_table_styles({
    'tbody tr:hover': [{'selector': 'td', 'props': [('background-color', '#f2f2f2')]}]
}, overwrite=False)

# 🖼️ Tabelle anzeigen
styled_df
# Out:
# <style type="text/css">
# #T_33df9 thead th {
#   background-color: #1f77b4;
#   color: white;
#   font-weight: bold;
# }
# #T_33df9 tbody td {
#   border: 1px solid #ddd;
#   text-align: center;
# }
# #T_33df9 td.col-1 {
#   background-color: #f2f2f2;
# }
# #T_33df9_row0_col0, #T_33df9_row0_col1, #T_33df9_row0_col2, #T_33df9_row0_col3, #T_33df9_row0_col4, #T_33df9_row0_col5, #T_33df9_row0_col6, #T_33df9_row0_col7, #T_33df9_row0_col8, #T_33df9_row0_col9, #T_33df9_row0_col10, #T_33df9_row0_col11, #T_33df9_row0_col12, #T_33df9_row0_col13, #T_33df9_row0_col14, #T_33df9_row0_col15, #T_33df9_row0_col16, #T_33df9_row0_col17, #T_33df9_row1_col0, #T_33df9_row1_col1, #T_33df9_row1_col2, #T_33df9_row1_col3, #T_33df9_row1_col4, #T_33df9_row1_col5, #T_33df9_row1_col6, #T_33df9_row1_col7, #T_33df9_row1_col8, #T_33df9_row1_col9, #T_33df9_row1_col10, #T_33df9_row1_col11, #T_33df9_row1_col12, #T_33df9_row1_col13, #T_33df9_row1_col14, #T_33df9_row1_col15, #T_33df9_row1_col16, #T_33df9_row1_col17, #T_33df9_row2_col0, #T_33df9_row2_col1, #T_33df9_row2_col2, #T_33df9_row2_col3, #T_33df9_row2_col4, #T_33df9_row2_col5, #T_33df9_row2_col6, #T_33df9_row2_col7, #T_33df9_row2_col8, #T_33df9_row2_col9, #T_33df9_row2_col10, #T_33df9_row2_col11, #T_33df9_row2_col12, #T_33df9_row2_col13, #T_33df9_row2_col14, #T_33df9_row2_col15, #T_33df9_row2_col16, #T_33df9_row2_col17, #T_33df9_row3_col0, #T_33df9_row3_col1, #T_33df9_row3_col2, #T_33df9_row3_col3, #T_33df9_row3_col4, #T_33df9_row3_col5, #T_33df9_row3_col
T_33df9_row9_col0, #T_33df9_row9_col1, #T_33df9_row9_col2, #T_33df9_row9_col3, #T_33df9_row9_col4, #T_33df9_row9_col5, #T_33df9_row9_col6, #T_33df9_row9_col7, #T_33df9_row9_col8, #T_33df9_row9_col9, #T_33df9_row9_col10, #T_33df9_row9_col11, #T_33df9_row9_col12, #T_33df9_row9_col13, #T_33df9_row9_col14, #T_33df9_row9_col15, #T_33df9_row9_col16, #T_33df9_row9_col17, #T_33df9_row10_col0, #T_33df9_row10_col1, #T_33df9_row10_col2, #T_33df9_row10_col3, #T_33df9_row10_col4, #T_33df9_row10_col5, #T_33df9_row10_col6, #T_33df9_row10_col7, #T_33df9_row10_col8, #T_33df9_row10_col9, #T_33df9_row10_col10, #T_33df9_row10_col11, #T_33df9_row10_col12, #T_33df9_row10_col13, #T_33df9_row10_col14,  ...

# %%
# ✅ Prüfen, ob Spalten existieren
if "SkinCancer" in df.columns and "HeartDisease" in df.columns:
    # 🔢 Kreuztabelle: wie viele mit/ohne Hautkrebs + Herzkrankheit
    table = pd.crosstab(df["SkinCancer"], df["HeartDisease"])

    # 🖼️ Balkendiagramm erstellen
    table.plot(kind='bar', stacked=False, figsize=(8,6), color=['skyblue', 'salmon'])
    plt.title('Anzahl der Personen mit/ohne Hautkrebs und Herzkrankheit')
    plt.xlabel('Skin Cancer')
    plt.ylabel('Anzahl der Personen')
    plt.xticks(rotation=0)
    plt.legend(title='Heart Disease')
    plt.tight_layout()
    plt.show()

    # 🎨 Schöne Tabelle (optional)
    styled_table = table.style.set_table_styles([
        {'selector': 'thead th', 'props': [('background-color', '#1f77b4'), ('color', 'white'), ('font-weight', 'bold')]},
        {'selector': 'tbody td', 'props': [('border', '1px solid #ddd'), ('text-align', 'center')]}
    ]).set_properties(**{'text-align': 'center'})

    styled_table

# %%
# ✅ Prüfen, ob Spalten existieren
if "Race" in df.columns and "HeartDisease" in df.columns:
    # 🔢 Kreuztabelle: wie viele mit/ohne Hautkrebs + Herzkrankheit
    table = pd.crosstab(df["Race"], df["HeartDisease"])

    # 🖼️ Balkendiagramm erstellen
    table.plot(kind='bar', stacked=False, figsize=(8,6), color=['skyblue', 'salmon'])
    plt.title('Anzahl der Personen mit/ohne Hautkrebs und Herzkrankheit')
    plt.xlabel('Skin Cancer')
    plt.ylabel('Anzahl der Personen')
    plt.xticks(rotation=0)
    plt.legend(title='Heart Disease')
    plt.tight_layout()
    plt.show()

    # 🎨 Schöne Tabelle (optional)
    styled_table = table.style.set_table_styles([
        {'selector': 'thead th', 'props': [('background-color', '#1f77b4'), ('color', 'white'), ('font-weight', 'bold')]},
        {'selector': 'tbody td', 'props': [('border', '1px solid #ddd'), ('text-align', 'center')]}
    ]).set_properties(**{'text-align': 'center'})

    styled_table
