# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\zahri\anaconda_projects\AsaiProjekt\Asai-Projekt\heart_2020_cleaned.csv")
#df = pd.read_csv("/Users/aurelia/Documents/GitHub/Asai-Projekt/heart_2020_cleaned.csv")
df_orginal = df.copy()

# %%
#DataFrame-Stylee
styled_df = df.head(10).style.set_table_styles([
    {'selector': 'thead th', 'props': [('background-color', '#1f77b4'), ('color', 'white'), ('font-weight', 'bold')]},
    {'selector': 'tbody td', 'props': [('border', '1px solid #ddd'), ('text-align', 'center')]}
]).set_properties(**{'text-align': 'center'})

styled_df
# Out:
# <style type="text/css">
# #T_677b0 thead th {
#   background-color: #1f77b4;
#   color: white;
#   font-weight: bold;
# }
# #T_677b0 tbody td {
#   border: 1px solid #ddd;
#   text-align: center;
# }
# #T_677b0_row0_col0, #T_677b0_row0_col1, #T_677b0_row0_col2, #T_677b0_row0_col3, #T_677b0_row0_col4, #T_677b0_row0_col5, #T_677b0_row0_col6, #T_677b0_row0_col7, #T_677b0_row0_col8, #T_677b0_row0_col9, #T_677b0_row0_col10, #T_677b0_row0_col11, #T_677b0_row0_col12, #T_677b0_row0_col13, #T_677b0_row0_col14, #T_677b0_row0_col15, #T_677b0_row0_col16, #T_677b0_row0_col17, #T_677b0_row1_col0, #T_677b0_row1_col1, #T_677b0_row1_col2, #T_677b0_row1_col3, #T_677b0_row1_col4, #T_677b0_row1_col5, #T_677b0_row1_col6, #T_677b0_row1_col7, #T_677b0_row1_col8, #T_677b0_row1_col9, #T_677b0_row1_col10, #T_677b0_row1_col11, #T_677b0_row1_col12, #T_677b0_row1_col13, #T_677b0_row1_col14, #T_677b0_row1_col15, #T_677b0_row1_col16, #T_677b0_row1_col17, #T_677b0_row2_col0, #T_677b0_row2_col1, #T_677b0_row2_col2, #T_677b0_row2_col3, #T_677b0_row2_col4, #T_677b0_row2_col5, #T_677b0_row2_col6, #T_677b0_row2_col7, #T_677b0_row2_col8, #T_677b0_row2_col9, #T_677b0_row2_col10, #T_677b0_row2_col11, #T_677b0_row2_col12, #T_677b0_row2_col13, #T_677b0_row2_col14, #T_677b0_row2_col15, #T_677b0_row2_col16, #T_677b0_row2_col17, #T_677b0_row3_col0, #T_677b0_row3_col1, #T_677b0_row3_col2, #T_677b0_row3_col3, #T_677b0_row3_col4, #T_677b0_row3_col5, #T_677b0_row3_col6, #T_677b0_row3_col7, #T_677b0_row3_col8, #T_677b0_row3_col9, #T_677b0_row3_col10, #T_677b0_row3_col11, #T_677b0_row3_col12, #T_677b0_row3_col13, #T_677b0_row3_col14, #T_677b0_row3_col15, #T_677b0_row3_col16, #T_677b0_row3_col17, #T_677b0_row4_col0, #T_677b0_row4_col1, #T_677b0_row4_col2, #T_677b0_row4_col3, #T_677b0_row4_col4, #T_677b0_row4_col5, #T_677b0_row4_col6, #T_677b0_row4_col7, #T_677b0_row4_col8, #T_677b0_row4_col9, #T_677b0_row4_col10, #T_677b0_row4_col11, #T_677b0_row4_col12, #T_677b0_row4_col13, #T_677b0_row4_col14, #T_677b0_row4_col15, #T_677b0_row4_col16, #T_677b0_row4_col17, #T_677b0_row5_col0, #T_677b0_row5_col1, #T_677b0_row5_col2, #T_677b0_row5_col3, #T_677b0_row5_col4, #T_677b0_row5_col5, #T_677b0_row5_col6, #T_677b0_row5_col7, #T_677b0_row5_col8, #T_677b0_row5_col9, #T_677b0_row5_col10, #T_677b0_row5_col11, #T_677b0_row5_col12, #T_677b0_row5_col13, #T_677b0_row5_col14, #T_677b0_row5_col15, #T_677b0_row5_col16, #T_677b0_row5_col17, #T_677b0_row6_col0, #T_677b0_row6_col1, #T_677b0_row6_col2, #T_677b0_row6_col3, #T_677b0_row6_col4, #T_677b0_row6_col5, #T_677b0_row6_col6, #T_677b0_row6_col7, #T_677b0_row6_col8, #T_677b0_row6_col9, #T_677b0_row6_col10, #T_677b0_row6_col11, #T_677b0_row6_col12, #T_677b0_row6_col13, #T_677b0_row6_col14, #T_677b0_row6_col15, #T_677b0_row6_col16, #T_677b0_row6_col17, #T_677b0_row7_col0, #T_677b0_row7_col1, #T_677b0_row7_col2, #T_677b0_row7_col3, #T_677b0_row7_col4, #T_677b0_row7_col5, #T_677b0_row7_col6, #T_677b0_row7_col7, #T_677b0_row7_col8, #T_677b0_row7_col9, #T_677b0_row7_col10, #T_677b0_row7_col11, #T_677b0_row7_col12, #T_677b0_row7_col13, #T_677b0_row7_col14, #T_677b0_row7_col15, #T_677b0_row7_col16, #T_677b0_row7_col17, #T_677b0_row8_col0, #T_677b0_row8_col1, #T_677b0_row8_col2, #T_677b0_row8_col3, #T_677b0_row8_col4, #T_677b0_row8_col5, #T_677b0_row8_col6, #T_677b0_row8_col7, #T_677b0_row8_col8, #T_677b0_row8_col9, #T_677b0_row8_col10, #T_677b0_row8_col11, #T_677b0_row8_col12, #T_677b0_row8_col13, #T_677b0_row8_col14, #T_677b0_row8_col15, #T_677b0_row8_col16, #T_677b0_row8_col17, #T_677b0_row9_col0, #T_677b0_row9_col1, #T_677b0_row9_col2, #T_677b0_row9_col3, #T_677b0_row9_col4, #T_677b0_row9_col5, #T_677b0_row9_col6, #T_677b0_row9_col7, #T_677b0_row9_col8, #T_677b0_row9_col9, #T_677b0_row9_col10, #T_677b0_row9_col11, #T_677b0_row9_col12, #T_677b0_row9_col13, #T_677b0_row9_col14, #T_677b0_row9_col15, #T_677b0_row9_col16, #T_677b0_row9_col17 {
#   text-align: center;
# }
# </style>
# <table id="T_677b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_677b0_level0_col0" class="col_heading level0 col0" >HeartDisease</th>
#       <th id="T_677b0_level0_col1" class="col_heading level0 col1" >BMI</th>
#       <th id="T_677b0_level0_col2" class="col_heading level0 col2" >Smoking</th>
#       <th id="T_677b0_level0_col3" class="col_heading level0 col3" >AlcoholDrinking</th>
#       <th id="T_677b0_level0_col4" class="col_heading level0 col4" >Stroke</th>
#       <th id="T_677b0_level0_col5" class="col_heading level0 col5" >PhysicalHealth</th>
#       <th id="T_677b0_level0_col6" class="col_heading level0 col6" >MentalHealth</th>
#       <th id="T_677b0_level0_col7" class="col_heading level0 col7" >DiffWalking</th>
#       <th id="T_677b0_level0_col8" class="col_heading level0 col8" >Sex</th>
#       <th id="T_677b0_level0_col9" class="col_heading level0 col9" >AgeCategory</th>
#       <th id="T_677b0_level0_col10" class="col_heading level0 col10" >Race</th>
#       <th id="T_677b0_level0_col11" class="col_heading level0 col11" >Diabetic</th>
#       <th id="T_677b0_level0_col12" class="col_heading level0 col12" >PhysicalActivity</th>
#       <th id="T_677b0_level0_col13" class="col_heading level0 col13" >GenHealth</th>
#       <th id="T_677b0_level0_col14" class="col_heading level0 col14" >SleepTime</th>
#       <th id="T_677b0_level0_col15" class="col_heading level0 col15" >Asthma</th>
#       <th id="T_677b0_level0_col16" class="col_heading level0 col16" >KidneyDisease</th>
#       <th id="T_677b0_level0_col17" class="col_heading level0 col17" >SkinCancer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_677b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_677b0_row0_col0" class="data row0 col0" >No</td>
#       <td id="T_677b0_row0_col1" class="data row0 col1" >16.600000</td>
#       <td id="T_677b0_row0_col2" class="data row0 col2" >Yes</td>
#       <td id="T_677b0_row0_col3" class="data row0 col3" >No</td>
#       <td id="T_677b0_row0_col4" class="data row0 col4" >No</td>
#       <td id="T_677b0_row0_col5" class="data row0 col5" >3.000000</td>
#       <td id="T_677b0_row0_col6" class="data row0 col6" >30.000000</td>
#       <td id="T_677b0_row0_col7" class="data row0 col7" >No</td>
#       <td id="T_677b0_row0_col8" class="data row0 col8" >Female</td>
#       <td id="T_677b0_row0_col9" class="data row0 col9" >55-59</td>
#       <td id="T_677b0_row0_col10" class="data row0 col10" >White</td>
#       <td id="T_677b0_row0_col11" class="data row0 col11" >Yes</td>
#       <td id="T_677b0_row0_col12" class="data row0 col12" >Yes</td>
#       <td id="T_677b0_row0_col13" class="data row0 col13" >Very good</td>
#       <td id="T_677b0_row0_col14" class="data row0 col14" >5.000000</td>
#       <td id="T_677b0_row0_col15" class="data row0 col15" >Yes</td>
#       <td id="T_677b0_row0_col16" class="data row0 col16" >No</td>
#       <td id="T_677b0_row0_col17" class="data row0 col17" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_677b0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_677b0_row1_col0" class="data row1 col0" >No</td>
#       <td id="T_677b0_row1_col1" class="data row1 col1" >20.340000</td>
#       <td id="T_677b0_row1_col2" class="data row1 col2" >No</td>
#       <td id="T_677b0_row1_col3" class="data row1 col3" >No</td>
#       <td id="T_677b0_row1_col4" class="data row1 col4" >Yes</td>
#       <td id="T_677b0_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_677b0_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_677b0_row1_col7" class="data row1 col7" >No</td>
#       <td id="T_677b0_row1_col8" class="data row1 col8" >Female</td>
#       <td id="T_677b0_row1_col9" class="data row1 col9" >80 or older</td>
#       <td id="T_677b0_row1_col10" class="data row1 col10" >White</td>
#       <td id="T_677b0_row1_col11" class="data row1 col11" >No</td>
#       <td id="T_677b0_row1_col12" class="data row1 col12" >Yes</td>
#       <td id="T_677b0_row1_col13" class="data row1 col13" >Very good</td>
#       <td id="T_677b0_row1_col14" class="data row1 col14" >7.000000</td>
#       <td id="T_677b0_row

# %%
# Alle duplizierten Zeilen (inkl. Erstvorkommen)
duplikate_df = df[df.duplicated(keep=False)]

# Anzahl und Prozent Duplikate
anzahl_duplikate = len(duplikate_df)
gesamt = len(df)
prozent_duplikate = (anzahl_duplikate / gesamt) * 100

# Verteilung HeartDisease in den Duplikaten
verteilung_duplikate = duplikate_df['HeartDisease'].value_counts(normalize=True) * 100

# Verteilung HeartDisease im gesamten DataFrame
verteilung_gesamt = df['HeartDisease'].value_counts(normalize=True) * 100

# Ausgabe
print("Gesamtzeilen:", gesamt)
print("Anzahl mehrfach vorkommender Zeilen:", anzahl_duplikate)
print(f"Prozent mehrfach vorkommend: {prozent_duplikate:.2f}%\n")

print("Verteilung innerhalb der Duplikate HeartDisease:")
for wert, proz in verteilung_duplikate.items():
    print(f"  {wert}: {proz:.2f}%")

print("\nGesamtverteilung HeartDisease:")
for wert, proz in verteilung_gesamt.items():
    print(f"  {wert}: {proz:.2f}%")
# Out:
# Gesamtzeilen: 319795
# Anzahl mehrfach vorkommender Zeilen: 29930
# Prozent mehrfach vorkommend: 9.36%
#
# Verteilung innerhalb der Duplikate:
#   No: 99.27%
#   Yes: 0.73%
#
# Gesamtverteilung HeartDisease:
#   No: 91.44%
#   Yes: 8.56%

# %%
# Alle vollständig doppelten Zeilen entfernen (exkl. erstes Vorkommen)
df_clean = df[~df.duplicated()]

# Neue Verteilung berechnen
verteilung_ohne_duplikate = df_clean['HeartDisease'].value_counts(normalize=True) * 100

# Ausgabe
print("Verteilung nach Entfernen aller doppelten Zeilen:")
for wert, proz in verteilung_ohne_duplikate.items():
    print(f"  {wert}: {proz:.2f}%")
# Out:
# Verteilung nach Entfernen aller doppelten Zeilen:
#   No: 90.96%
#   Yes: 9.04%
